# %% [markdown]
# <a href="https://colab.research.google.com/github/zahraDehghanian97/overlapped_medicine/blob/master/overlapped_medicine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
df = pandas.read_excel('/content/medicine_overlap.xlsx')

#print the column names
df.columns
# Out:
# Index(['ردیف', 'استان', 'بیمارستان', 'جنسیت', 'تاریخ تولد', 'سن',
#        'محل سکونت در سال گذشته', 'تاریخ شروع اولین علائم ام اس',
#        'سن شروع اولین علائم ام اس', 'تاریخ تشخیص بیماری ام اس توسط پزشک',
#        'سن تشخیص بیماری ام اس توسط پزشک', 'نوع بیماری ام اس',
#        'تعداد کل بستری ها در بیمارستان به علت بیماری ام اس',
#        'آیا بیماری شما به ام اس پیشرونده ثانویه تبدیل شده',
#        'پیشرونده - چه سالی', 'نمره EDSS', 'داروی سیکلوفسفوماید',
#        'سال شروع دارو (سیکلوفسفوماید)', 'قطع دارو (سیکلوفسفوماید)',
#        'سال قطع دارو (سیکلوفسفوماید)', 'داروی ربیف/رسیژن/سان ریف/اکتوریف',
#        'سال شروع دارو(ربیف/رسیژن/سان ریف/اکتوریف)',
#        'قطع دارو (ربیف/رسیژن/سان ریف/اکتوریف)',
#        'سال قطع دارو(ربیف/رسیژن/سان ریف/اکتوریف)',
#        'داروی بتافرون/اکستویا/اکتوفرون/زیفرون/اکتوفرون',
#        'سال شروع دارو (بتافرون/اکستویا/اکتوفرون/زیفرون/اکتوفرون)',
#        'قطع دارو (بتافرون/اکستویا/اکتوفرون/زیفرون/اکتوفرون)',
# ...

# %%
#get the values for a given column
values = df['column_name'].values

#get a data frame with selected columns
FORMAT = ['Col_1', 'Col_2', 'Col_3']
df_selected = df[FORMAT]
